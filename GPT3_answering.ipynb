# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import json
# f = open("/content/drive/MyDrive/Finance QA/data/used_data/valid_unfiltered_qa_pairs_with_data.json",)
# data = json.load(f)

# print(len(data))
# f.close()

# %%
import pandas as pd
url = '/content/drive/MyDrive/Finance QA/data/used_data/GPT3_sample_outputs.csv'
df = pd.read_csv(url)

# %%
from pprint import pprint

# %%
df['prompts'][0]
# Out:
# 'Create a list of questions from the paragraph below: Hi, good morning. Thanks for the question. I appreciate the early selling season comments for the PBM for 2020. Just wanted to get a little more color if there are particular pockets of strength that you are seeing in the 2020 selling season, especially as I think you had mentioned last year you won about three health plan clients on your 2Q call? Thank you. 1. '
